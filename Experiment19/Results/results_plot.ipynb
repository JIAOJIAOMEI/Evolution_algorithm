# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
# pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)

# %%
# Load data
params = pd.read_csv('/Users/meijiaojiao/Desktop/Evolution_algorithm/Experiment19/Experiment_F5/parameter_combinations.csv',
                        sep=',', header=0, index_col=0)
print(params.shape)
print(params)
# Out:
# (15, 17)
#     num_generations  mutation_rate  num_individuals  crossover_rate  \
# 0           1000000           0.03              200             0.7
# 1           1000000           0.03              200             0.7
# 2           1000000           0.03              200             0.7
# 3           1000000           0.03              100             0.7
# 4           1000000           0.03              100             0.7
# 5           1000000           0.03              100             0.7
# 6           1000000           0.03              200             0.6
# 7           1000000           0.03              200             0.6
# 8           1000000           0.03              200             0.6
# 9           1000000           0.03              100             0.6
# 10          1000000           0.03              100             0.6
# 11          1000000           0.03              100             0.6
# 12          1000000           0.03              200             0.7
# 13          1000000           0.03              200             0.7
# 14          1000000           0.03              200             0.7
#
#    mutation_type           crossover_type  local_search_rate  \
# 0         Normal  Probabilistic_crossover                0.5
# 1         Normal  Probabilistic_crossover                0.5
# 2         Normal  Probabilistic_crossover                0.5
# 3         Normal  Probabilistic_crossover                0.5
# 4         Normal  Probabilistic_crossover                0.5
# 5         Normal  Probabilistic_crossover                0.5
# 6         Normal  Probabilistic_crossover                0.5
# 7         Normal  Probabilistic_crossover                0.5
# 8         Normal  Probabilistic_crossover                0.5
# 9         Normal  Probabilistic_crossover                0.5
# 10        Normal  Probabilistic_crossover                0.5
# 11        Normal  Probabilistic_crossover                0.5
# 12        Normal  Probabilistic_crossover                0.5
# 13        Normal  Probabilistic_crossover                0.5
# 14        Normal  Probabilistic_crossover                0.5
#
#    local_search_type  search_radius  threshold  dimensions    gg  \
# 0            Uniform           0.05     0.0001         100  0.05
# 1            Uniform           0.05     0.0001         100  0.05
# 2            Uniform           0.05     0.0001         100  0.05
# 3            Uniform           0.05     0.0001         100  0.05
# 4            Uniform           0.05     0.0001         100  0.05
# 5            Uniform           0.05     0.0001         100  0.05
# 6            Uniform           0.05     0.0001         100  0.05
# 7            Uniform           0.05     0.0001         100  0.05
# 8            Uniform           0.05     0.0001         100  0.05
# 9            Uniform           0.05     0.0001         100  0.05
# 10           Uniform           0.05     0.0001         100  0.05
# 11           Uniform           0.05     0.0001         100  0.05
# 12           Uniform           0.05     0.0001         100  0.05
# 13           Uniform           0.05     0.0001         100  0.05
# 14           Uniform           0.05     0.0001         100  0.05
#
#          selection_method  length_of_local_search  redo_local_search_rate  \
# 0   sorted_selection_part                       1                       0
# 1   sorted_selection_part                       1                       0
# 2   sorted_selection_part                       1                       0
# 3   sorted_selection_part                       1                       0
# 4   sorted_selection_part                       1                       0
# 5   sorted_selection_part                       1                       0
# 6   sorted_selection_part                       4                       0
# 7   sorted_selection_part                       4                       0
# 8   sorted_selection_part                       4                       0
# 9   sorted_selection_part                       4                       0
# 10  sorted_selection_part                       4                       0
# 11  sorted_selection_part                       4                       0
# 12  sorted_selection_part                       4                       0
# 13  sorted_selection_part                       4                       0
# 14  sorted_selection_part                       4                       0
#
#     fitness_function algorithm
# 0                  5  Baseline
# 1                  5   Lamarck
# 2                  5   Baldwin
# 3                  5  Baseline
# 4                  5   Lamarck
# 5                  5   Baldwin
# 6                  5  Baseline
# 7                  5   Lamarck
# 8                  5   Baldwin
# 9                  5  Baseline
# 10                 5   Lamarck
# 11                 5   Baldwin
# 12                 5  Baseline
# 13                 5   Lamarck
# 14                 5   Baldwin

# %%
best_fitness_F5 = np.loadtxt('/Users/meijiaojiao/Desktop/Evolution_algorithm/Experiment19/Experiment_F5/best_fitness_F5.txt')
print(best_fitness_F5.shape)
best_fitness_F5 = best_fitness_F5.tolist()
print(best_fitness_F5[0:10])
# Out:
# (2320,)
# [915256729.7938931, 292412585.64892, 129914161.49058463, 64174879.08427246, 34151740.36785649, 17871783.087272283, 9014610.246825282, 4877577.702708304, 3075118.0352229048, 1752351.043777272]

# %%
solution_F5 = pd.read_csv('/Users/meijiaojiao/Desktop/Evolution_algorithm/Experiment19/Experiment_F5/solutions_dataframe.csv',sep=',', header=0, index_col=0)
print(solution_F5.shape)
# Out:
# (15, 10)

# %%
with open('/Users/meijiaojiao/Desktop/Evolution_algorithm/Experiment19/Experiment_F5/fitness_F5.txt', 'r') as f:
    fitness_F5 = f.readlines()
print(len(fitness_F5))
# Out:
# 2320

# %%
counter = 0
index_list = [0]
for index,value in enumerate(best_fitness_F5):
    if index > 0:
        if value > best_fitness_F5[index-1]:
            index_list.append(index)
            gap = index - index_list[-2]
            counter += 1
            print("The index is %d, the value is %f, the counter is %d, the gap is %d" % (index, value, counter, gap))
best_fitness_F5_sublist = []
for i in range(len(index_list)):
    if i < len(index_list)-1:
        best_fitness_F5_sublist.append(best_fitness_F5[index_list[i]:index_list[i+1]])
    else:
        best_fitness_F5_sublist.append(best_fitness_F5[index_list[i]:])
print(len(best_fitness_F5_sublist))
# Out:
# The index is 20, the value is 1077706532.627216, the counter is 1, the gap is 20
# The index is 40, the value is 956920057.481968, the counter is 2, the gap is 20
# The index is 60, the value is 1016849590.427756, the counter is 3, the gap is 20
# The index is 80, the value is 1024719826.814175, the counter is 4, the gap is 20
# The index is 100, the value is 1032986390.193703, the counter is 5, the gap is 20
# The index is 120, the value is 991011759.817493, the counter is 6, the gap is 20
# The index is 140, the value is 1064355890.538751, the counter is 7, the gap is 20
# The index is 160, the value is 1076554370.645997, the counter is 8, the gap is 20
# The index is 180, the value is 1052644039.972182, the counter is 9, the gap is 20
# The index is 200, the value is 1010671048.456969, the counter is 10, the gap is 20
# The index is 210, the value is 956057355.708878, the counter is 11, the gap is 10
# The index is 220, the value is 952901813.522639, the counter is 12, the gap is 10
# The index is 230, the value is 953052217.755777, the counter is 13, the gap is 10
# The index is 240, the value is 917777538.958965, the counter is 14, the gap is 10
# The index is 250, the value is 1099653083.219180, the counter is 15, the gap is 10
# The index is 260, the value is 980477818.731515, the counter is 16, the gap is 10
# The index is 270, the value is 1073687736.259760, the counter is 17, the gap is 10
# The index is 280, the value is 1030073744.894849, the counter is 18, the gap is 10
# The index is 290, the value is 1076276075.336193, the counter is 19, the gap is 10
# The index is 300, the value is 1111908002.397012, the counter is 20, the gap is 10
# The index is 310, the value is 1120719254.618351, the counter is 21, the gap is 10
# The index is 320, the value is 1001913390.997335, the counter is 22, the gap is 10
# The index is 330, the value is 1181414699.462052, the counter is 23, the gap is 10
# The index is 340, the value is 1065352131.501722, the counter is 24, the gap is 10
# The index is 350, the value is 1039899595.478708, the counter is 25, the gap is 10
# The index is 360, the value is 962881110.555692, the counter is 26, the gap is 10
# The index is 370, the value is 1068372473.121578, the counter is 27, the gap is 10
# The index is 380, the value is 1026799025.346052, the counter is 28, the gap is 10
# The index is 390, the value is 953975838.294314, the counter is 29, the gap is 10
# The index is 400, the value is 976711143.716749, the counter is 30, the gap is 10
# The index is 440, the value is 1120723899.479606, the counter is 31, the gap is 40
# The index is 480, the value is 1035325131.119139, the counter is 32, the gap is 40
# The index is 520, the value is 1191230322.475714, the counter is 33, the gap is 40
# The index is 560, the value is 1072517898.771032, the counter is 34, the gap is 40
# The index is 600, the value is 1128863427.461096, the counter is 35, the gap is 40
# The index is 640, the value is 1130975680.467475, the counter is 36, the gap is 40
# The index is 680, the value is 1051970314.663436, the counter is 37, the gap is 40
# The index is 720, the value is 968300436.400833, the counter is 38, the gap is 40
# The index is 760, the value is 1140903602.078164, the counter is 39, the gap is 40
# The index is 800, the value is 1050982129.961480, the counter is 40, the gap is 40
# The index is 820, the value is 1032581124.403400, the counter is 41, the gap is 20
# The index is 840, the value is 971155601.488601, the counter is 42, the gap is 20
# The index is 860, the value is 1110516929.156375, the counter is 43, the gap is 20
# The index is 880, the value is 1087158960.570213, the counter is 44, the gap is 20
# The index is 900, the value is 815993564.375335, the counter is 45, the gap is 20
# The index is 920, the value is 977031668.818670, the counter is 46, the gap is 20
# The index is 940, the value is 1135854773.378272, the counter is 47, the gap is 20
# The index is 960, the value is 1129706123.758161, the counter is 48, the gap is 20
# The index is 980, the value is 1006399690.680553, the counter is 49, the gap is 20
# The index is 1000, the value is 969060625.421159, the counter is 50, the gap is 20
# The index is 1020, the value is 1095199805.056167, the counter is 51, the gap is 20
# The index is 1040, the value is 1058263188.884286, the counter is 52, the gap is 20
# The index is 1060, the value is 1040824714.618467, the counter is 53, the gap is 20
# The index is 1080, the value is 994946396.253263, the counter is 54, the gap is 20
# The index is 1100, the value is 988287228.023203, the counter is 55, the gap is 20
# The index is 1120, the value is 1083086172.971416, the counter is 56, the gap is 20
# The index is 1140, the value is 1123539921.131444, the counter is 57, the gap is 20
# The index is 1160, the value is 1082116219.447897, the counter is 58, the gap is 20
# The index is 1180, the value is 1008799280.386436, the counter is 59, the gap is 20
# The index is 1200, the value is 996722831.104169, the counter is 60, the gap is 20
# The index is 1220, the value is 1013385709.377328, the counter is 61, the gap is 20
# The index is 1240, the value is 951419804.154847, the counter is 62, the gap is 20
# The index is 1260, the value is 1078048327.504450, the counter is 63, the gap is 20
# The index is 1280, the value is 1075413265.142082, the counter is 64, the gap is 20
# The index is 1300, the value is 818678835.412752, the counter is 65, the gap is 20
# The index is 1320, the value is 861070701.097685, the counter is 66, the gap is 20
# The index is 1340, the value is 1063896976.032350, the counter is 67, the gap is 20
# The index is 1360, the value is 1094228332.884300, the counter is 68, the gap is 20
# The index is 1380, the value is 958743355.377257, the counter is 69, the gap is 20
# The index is 1400, the value is 987570312.521269, the counter is 70, the gap is 20
# The index is 1404, the value is 924581306.786537, the counter is 71, the gap is 4
# The index is 1408, the value is 988689938.926396, the counter is 72, the gap is 4
# The index is 1412, the value is 774795834.818913, the counter is 73, the gap is 4
# The index is 1416, the value is 1070358774.263359, the counter is 74, the gap is 4
# The index is 1420, the value is 867221400.047567, the counter is 75, the gap is 4
# The index is 1424, the value is 990667474.117192, the counter is 76, the gap is 4
# The index is 1428, the value is 928939901.371787, the counter is 77, the gap is 4
# The index is 1432, the value is 907588915.635657, the counter is 78, the gap is 4
# The index is 1436, the value is 1065098760.558653, the counter is 79, the gap is 4
# The index is 1440, the value is 933276867.562938, the counter is 80, the gap is 4
# The index is 1444, the value is 1030959598.066680, the counter is 81, the gap is 4
# The index is 1448, the value is 1005447821.380976, the counter is 82, the gap is 4
# The index is 1452, the value is 1020429593.842887, the counter is 83, the gap is 4
# The index is 1456, the value is 1032482748.841859, the counter is 84, the gap is 4
# The index is 1460, the value is 995326683.221125, the counter is 85, the gap is 4
# The index is 1464, the value is 888689416.546247, the counter is 86, the gap is 4
# The index is 1468, the value is 1041350114.602742, the counter is 87, the gap is 4
# The index is 1472, the value is 1067722301.854167, the counter is 88, the gap is 4
# The index is 1476, the value is 986379966.746976, the counter is 89, the gap is 4
# The index is 1480, the value is 1092245744.812728, the counter is 90, the gap is 4
# The index is 1520, the value is 984304613.103990, the counter is 91, the gap is 40
# The index is 1560, the value is 1074899646.771274, the counter is 92, the gap is 40
# The index is 1600, the value is 888510042.000598, the counter is 93, the gap is 40
# The index is 1640, the value is 1057884208.650891, the counter is 94, the gap is 40
# The index is 1680, the value is 1084473445.911963, the counter is 95, the gap is 40
# The index is 1720, the value is 1100745383.972425, the counter is 96, the gap is 40
# The index is 1760, the value is 997426544.574883, the counter is 97, the gap is 40
# The index is 1800, the value is 1083418888.317654, the counter is 98, the gap is 40
# The index is 1840, the value is 1172938488.556413, the counter is 99, the gap is 40
# The index is 1880, the value is 1030970437.867581, the counter is 100, the gap is 40
# The index is 1888, the value is 1103915968.884658, the counter is 101, the gap is 8
# The index is 1896, the value is 1096803975.146990, the counter is 102, the gap is 8
# The index is 1904, the value is 1058466637.042521, the counter is 103, the gap is 8
# The index is 1912, the value is 1022467792.918939, the counter is 104, the gap is 8
# The index is 1920, the value is 990742235.389516, the counter is 105, the gap is 8
# The index is 1928, the value is 983644384.886934, the counter is 106, the gap is 8
# The index is 1936, the value is 951087705.084359, the counter is 107, the gap is 8
# The index is 1944, the value is 1046737905.593476, the counter is 108, the gap is 8
# The index is 1952, the value is 932478609.434907, the counter is 109, the gap is 8
# The index is 1960, the value is 963321989.685494, the counter is 110, the gap is 8
# The index is 1968, the value is 1063591127.985751, the counter is 111, the gap is 8
# The index is 1976, the value is 1140875704.412875, the counter is 112, the gap is 8
# The index is 1984, the value is 1058495754.526613, the counter is 113, the gap is 8
# The index is 1992, the value is 946353461.459989, the counter is 114, the gap is 8
# The index is 2000, the value is 963403693.855221, the counter is 115, the gap is 8
# The index is 2008, the value is 1033558971.968890, the counter is 116, the gap is 8
# The index is 2016, the value is 1049862752.961044, the counter is 117, the gap is 8
# The index is 2024, the value is 900076903.266991, the counter is 118, the gap is 8
# The index is 2032, the value is 891513746.576216, the counter is 119, the gap is 8
# The index is 2040, the value is 885646895.557017, the counter is 120, the gap is 8
# The index is 2060, the value is 1056572569.942810, the counter is 121, the gap is 20
# The index is 2080, the value is 844377812.211370, the counter is 122, the gap is 20
# The index is 2100, the value is 996896018.720296, the counter is 123, the gap is 20
# The index is 2120, the value is 992154463.402994, the counter is 124, the gap is 20
# The index is 2140, the value is 1087943648.578581, the counter is 125, the gap is 20
# The index is 2160, the value is 1073506310.696719, the counter is 126, the gap is 20
# The index is 2180, the value is 1062182042.291708, the counter is 127, the gap is 20
# The index is 2200, the value is 1127579721.628408, the counter is 128, the gap is 20
# The index is 2220, the value is 1132344806.218199, the counter is 129, the gap is 20
# The index is 2240, the value is 982194056.554175, the counter is 130, the gap is 20
# The index is 2244, the value is 960027953.841430, the counter is 131, the gap is 4
# The index is 2248, the value is 1005002656.486835, the counter is 132, the gap is 4
# The index is 2252, the value is 938591973.547831, the counter is 133, the gap is 4
# The index is 2256, the value is 1012857717.054624, the counter is 134, the gap is 4
# The index is 2260, the value is 1034703359.441173, the counter is 135, the gap is 4
# The index is 2264, the value is 920083490.707470, the counter is 136, the gap is 4
# The index is 2268, the value is 944881582.912979, the counter is 137, the gap is 4
# The index is 2272, the value is 849072183.665933, the counter is 138, the gap is 4
# The index is 2276, the value is 972176045.851192, the counter is 139, the gap is 4
# The index is 2280, the value is 815922376.820804, the counter is 140, the gap is 4
# The index is 2284, the value is 974782819.648303, the counter is 141, the gap is 4
# The index is 2288, the value is 909564017.913888, the counter is 142, the gap is 4
# The index is 2292, the value is 940938229.262629, the counter is 143, the gap is 4
# The index is 2296, the value is 1117227704.017671, the counter is 144, the gap is 4
# The index is 2300, the value is 848503669.569454, the counter is 145, the gap is 4
# The index is 2304, the value is 1005545497.754809, the counter is 146, the gap is 4
# The index is 2308, the value is 1095065534.625709, the counter is 147, the gap is 4
# The index is 2312, the value is 920027871.761858, the counter is 148, the gap is 4
# The index is 2316, the value is 948071123.618314, the counter is 149, the gap is 4
# 150

# %%
# load the data for F8
best_fitness_F8 = np.loadtxt('/Users/meijiaojiao/Desktop/Evolution_algorithm/Experiment19/Experiment_F8/best_fitness_F8.txt')
print(best_fitness_F8.shape)
best_fitness_F8 = best_fitness_F8.tolist()
solution_F8 = pd.read_csv('/Users/meijiaojiao/Desktop/Evolution_algorithm/Experiment19/Experiment_F8/solutions_dataframe.csv',sep=',', header=0, index_col=0)
print(solution_F8.shape)
with open('/Users/meijiaojiao/Desktop/Evolution_algorithm/Experiment19/Experiment_F8/fitness_F8.txt', 'r') as f:
    fitness_F8 = f.readlines()
print(len(fitness_F8[491:]))
counter = 0
index_list = [0]
for index,value in enumerate(best_fitness_F8):
    if index > 0:
        if value > best_fitness_F8[index-1]:
            index_list.append(index)
            gap = index - index_list[-2]
            counter += 1
            print("The index is %d, the value is %f, the counter is %d, the gap is %d" % (index, value, counter, gap))
best_fitness_F8_sublist = []
for i in range(len(index_list)):
    if i < len(index_list)-1:
        best_fitness_F8_sublist.append(best_fitness_F8[index_list[i]:index_list[i+1]])
    else:
        best_fitness_F8_sublist.append(best_fitness_F8[index_list[i]:])
print(len(best_fitness_F8_sublist))
# Out:
# (2320,)
# (15, 10)
# 1829
# The index is 20, the value is -5315.009333, the counter is 1, the gap is 20
# The index is 40, the value is -5572.227471, the counter is 2, the gap is 20
# The index is 60, the value is -5292.858902, the counter is 3, the gap is 20
# The index is 80, the value is -7812.354312, the counter is 4, the gap is 20
# The index is 100, the value is -6134.125798, the counter is 5, the gap is 20
# The index is 120, the value is -5339.590659, the counter is 6, the gap is 20
# The index is 140, the value is -5110.347832, the counter is 7, the gap is 20
# The index is 160, the value is -4820.058491, the counter is 8, the gap is 20
# The index is 180, the value is -5492.940519, the counter is 9, the gap is 20
# The index is 200, the value is -7638.586624, the counter is 10, the gap is 20
# The index is 210, the value is -5469.043354, the counter is 11, the gap is 10
# The index is 220, the value is -7902.761854, the counter is 12, the gap is 10
# The index is 230, the value is -5541.307684, the counter is 13, the gap is 10
# The index is 240, the value is -6771.040569, the counter is 14, the gap is 10
# The index is 250, the value is -6017.435416, the counter is 15, the gap is 10
# The index is 260, the value is -5146.928289, the counter is 16, the gap is 10
# The index is 270, the value is -5780.100612, the counter is 17, the gap is 10
# The index is 280, the value is -4931.600454, the counter is 18, the gap is 10
# The index is 290, the value is -5785.414702, the counter is 19, the gap is 10
# The index is 300, the value is -6563.054018, the counter is 20, the gap is 10
# The index is 310, the value is -5928.011438, the counter is 21, the gap is 10
# The index is 320, the value is -5468.456998, the counter is 22, the gap is 10
# The index is 330, the value is -6159.263263, the counter is 23, the gap is 10
# The index is 340, the value is -5044.615526, the counter is 24, the gap is 10
# The index is 350, the value is -6446.060286, the counter is 25, the gap is 10
# The index is 360, the value is -5342.471939, the counter is 26, the gap is 10
# The index is 370, the value is -6328.438842, the counter is 27, the gap is 10
# The index is 380, the value is -7307.486490, the counter is 28, the gap is 10
# The index is 390, the value is -4958.383462, the counter is 29, the gap is 10
# The index is 400, the value is -4766.279637, the counter is 30, the gap is 10
# The index is 440, the value is -5710.244150, the counter is 31, the gap is 40
# The index is 480, the value is -5680.832928, the counter is 32, the gap is 40
# The index is 520, the value is -5989.658400, the counter is 33, the gap is 40
# The index is 560, the value is -3597.181364, the counter is 34, the gap is 40
# The index is 600, the value is -4194.520138, the counter is 35, the gap is 40
# The index is 640, the value is -3932.995690, the counter is 36, the gap is 40
# The index is 680, the value is -4837.300941, the counter is 37, the gap is 40
# The index is 720, the value is -5889.206569, the counter is 38, the gap is 40
# The index is 760, the value is -4351.651361, the counter is 39, the gap is 40
# The index is 800, the value is -5515.747771, the counter is 40, the gap is 40
# The index is 820, the value is -5460.189385, the counter is 41, the gap is 20
# The index is 840, the value is -5331.416954, the counter is 42, the gap is 20
# The index is 860, the value is -6050.876129, the counter is 43, the gap is 20
# The index is 880, the value is -5836.957208, the counter is 44, the gap is 20
# The index is 900, the value is -4845.712030, the counter is 45, the gap is 20
# The index is 920, the value is -5307.259277, the counter is 46, the gap is 20
# The index is 940, the value is -5805.878186, the counter is 47, the gap is 20
# The index is 960, the value is -5177.170978, the counter is 48, the gap is 20
# The index is 980, the value is -6878.074546, the counter is 49, the gap is 20
# The index is 1000, the value is -5401.576156, the counter is 50, the gap is 20
# The index is 1020, the value is -5141.267197, the counter is 51, the gap is 20
# The index is 1040, the value is -5064.133346, the counter is 52, the gap is 20
# The index is 1060, the value is -4545.649655, the counter is 53, the gap is 20
# The index is 1080, the value is -5633.141471, the counter is 54, the gap is 20
# The index is 1100, the value is -5723.265510, the counter is 55, the gap is 20
# The index is 1120, the value is -4826.613829, the counter is 56, the gap is 20
# The index is 1140, the value is -5534.270710, the counter is 57, the gap is 20
# The index is 1160, the value is -5758.880556, the counter is 58, the gap is 20
# The index is 1180, the value is -5286.066287, the counter is 59, the gap is 20
# The index is 1200, the value is -5942.556072, the counter is 60, the gap is 20
# The index is 1220, the value is -4866.433223, the counter is 61, the gap is 20
# The index is 1240, the value is -6151.116307, the counter is 62, the gap is 20
# The index is 1260, the value is -5072.462795, the counter is 63, the gap is 20
# The index is 1280, the value is -6179.340056, the counter is 64, the gap is 20
# The index is 1300, the value is -4815.967401, the counter is 65, the gap is 20
# The index is 1320, the value is -5525.996694, the counter is 66, the gap is 20
# The index is 1340, the value is -5437.965602, the counter is 67, the gap is 20
# The index is 1360, the value is -5479.475565, the counter is 68, the gap is 20
# The index is 1380, the value is -6173.101918, the counter is 69, the gap is 20
# The index is 1400, the value is -7357.735838, the counter is 70, the gap is 20
# The index is 1404, the value is -5634.742492, the counter is 71, the gap is 4
# The index is 1408, the value is -7133.040357, the counter is 72, the gap is 4
# The index is 1412, the value is -7700.153060, the counter is 73, the gap is 4
# The index is 1416, the value is -7270.677976, the counter is 74, the gap is 4
# The index is 1420, the value is -6259.655594, the counter is 75, the gap is 4
# The index is 1424, the value is -7420.542369, the counter is 76, the gap is 4
# The index is 1428, the value is -6643.288562, the counter is 77, the gap is 4
# The index is 1432, the value is -5713.315025, the counter is 78, the gap is 4
# The index is 1436, the value is -6037.702511, the counter is 79, the gap is 4
# The index is 1440, the value is -5395.732852, the counter is 80, the gap is 4
# The index is 1444, the value is -5878.274663, the counter is 81, the gap is 4
# The index is 1448, the value is -6085.240247, the counter is 82, the gap is 4
# The index is 1452, the value is -6395.061800, the counter is 83, the gap is 4
# The index is 1456, the value is -6449.685923, the counter is 84, the gap is 4
# The index is 1460, the value is -5884.913477, the counter is 85, the gap is 4
# The index is 1464, the value is -6339.518592, the counter is 86, the gap is 4
# The index is 1468, the value is -6537.156707, the counter is 87, the gap is 4
# The index is 1472, the value is -6967.739069, the counter is 88, the gap is 4
# The index is 1476, the value is -6049.868165, the counter is 89, the gap is 4
# The index is 1480, the value is -6491.724389, the counter is 90, the gap is 4
# The index is 1520, the value is -5752.932694, the counter is 91, the gap is 40
# The index is 1560, the value is -5121.802013, the counter is 92, the gap is 40
# The index is 1600, the value is -4557.357386, the counter is 93, the gap is 40
# The index is 1640, the value is -4240.532448, the counter is 94, the gap is 40
# The index is 1680, the value is -4419.100660, the counter is 95, the gap is 40
# The index is 1720, the value is -6229.988561, the counter is 96, the gap is 40
# The index is 1760, the value is -4995.127799, the counter is 97, the gap is 40
# The index is 1800, the value is -6858.203764, the counter is 98, the gap is 40
# The index is 1840, the value is -3875.909285, the counter is 99, the gap is 40
# The index is 1880, the value is -5274.922653, the counter is 100, the gap is 40
# The index is 1888, the value is -6458.561868, the counter is 101, the gap is 8
# The index is 1896, the value is -5715.824645, the counter is 102, the gap is 8
# The index is 1904, the value is -6063.164796, the counter is 103, the gap is 8
# The index is 1912, the value is -6284.456949, the counter is 104, the gap is 8
# The index is 1920, the value is -6303.434237, the counter is 105, the gap is 8
# The index is 1928, the value is -6602.278218, the counter is 106, the gap is 8
# The index is 1936, the value is -6611.753952, the counter is 107, the gap is 8
# The index is 1944, the value is -5635.282141, the counter is 108, the gap is 8
# The index is 1952, the value is -6717.818684, the counter is 109, the gap is 8
# The index is 1960, the value is -6369.822341, the counter is 110, the gap is 8
# The index is 1968, the value is -7053.452023, the counter is 111, the gap is 8
# The index is 1976, the value is -5407.895788, the counter is 112, the gap is 8
# The index is 1984, the value is -4760.381094, the counter is 113, the gap is 8
# The index is 1992, the value is -9142.506550, the counter is 114, the gap is 8
# The index is 2000, the value is -5949.559286, the counter is 115, the gap is 8
# The index is 2008, the value is -5565.831379, the counter is 116, the gap is 8
# The index is 2016, the value is -5674.694987, the counter is 117, the gap is 8
# The index is 2024, the value is -6965.984072, the counter is 118, the gap is 8
# The index is 2032, the value is -5942.237359, the counter is 119, the gap is 8
# The index is 2040, the value is -5434.344115, the counter is 120, the gap is 8
# The index is 2060, the value is -6234.642364, the counter is 121, the gap is 20
# The index is 2080, the value is -5159.858663, the counter is 122, the gap is 20
# The index is 2100, the value is -4340.164753, the counter is 123, the gap is 20
# The index is 2120, the value is -4763.107469, the counter is 124, the gap is 20
# The index is 2140, the value is -7363.332733, the counter is 125, the gap is 20
# The index is 2160, the value is -6990.240548, the counter is 126, the gap is 20
# The index is 2180, the value is -6201.304794, the counter is 127, the gap is 20
# The index is 2200, the value is -4928.326429, the counter is 128, the gap is 20
# The index is 2220, the value is -4895.137071, the counter is 129, the gap is 20
# The index is 2240, the value is -5855.861404, the counter is 130, the gap is 20
# The index is 2244, the value is -6388.240088, the counter is 131, the gap is 4
# The index is 2248, the value is -6558.176757, the counter is 132, the gap is 4
# The index is 2252, the value is -6263.440976, the counter is 133, the gap is 4
# The index is 2256, the value is -6280.467445, the counter is 134, the gap is 4
# The index is 2260, the value is -6577.969830, the counter is 135, the gap is 4
# The index is 2264, the value is -7069.876522, the counter is 136, the gap is 4
# The index is 2268, the value is -6286.546427, the counter is 137, the gap is 4
# The index is 2272, the value is -6549.530678, the counter is 138, the gap is 4
# The index is 2276, the value is -6697.351923, the counter is 139, the gap is 4
# The index is 2280, the value is -6823.830919, the counter is 140, the gap is 4
# The index is 2284, the value is -5589.549406, the counter is 141, the gap is 4
# The index is 2288, the value is -6619.692541, the counter is 142, the gap is 4
# The index is 2292, the value is -5797.377784, the counter is 143, the gap is 4
# The index is 2296, the value is -5981.460529, the counter is 144, the gap is 4
# The index is 2300, the value is -6136.335261, the counter is 145, the gap is 4
# The index is 2304, the value is -5918.734605, the counter is 146, the gap is 4
# The index is 2308, the value is -5632.101927, the counter is 147, the gap is 4
# The index is 2312, the value is -6191.438474, the counter is 148, the gap is 4
# The index is 2316, the value is -8163.708100, the counter is 149, the gap is 4
# 150

# %%
# load the data for F21
best_fitness_F21 = np.loadtxt('/Users/meijiaojiao/Desktop/Evolution_algorithm/Experiment19/Experiment_F21/best_fitness_F21.txt')
print(best_fitness_F21.shape)
best_fitness_F21 = best_fitness_F21.tolist()
solution_F21 = pd.read_csv('/Users/meijiaojiao/Desktop/Evolution_algorithm/Experiment19/Experiment_F21/solutions_dataframe.csv',sep=',', header=0, index_col=0)
print(solution_F21.shape)
with open('/Users/meijiaojiao/Desktop/Evolution_algorithm/Experiment19/Experiment_F21/fitness_F21.txt', 'r') as f:
    fitness_F21 = f.readlines()
print(len(fitness_F21))
counter = 0
index_list = [0]
for index,value in enumerate(best_fitness_F21):
    if index > 0:
        if value > best_fitness_F21[index-1]:
            index_list.append(index)
            gap = index - index_list[-2]
            counter += 1
            print("The index is %d, the value is %f, the counter is %d, the gap is %d" % (index, value, counter, gap))
index_list.insert(0, 1412)
index_list = sorted(index_list)
best_fitness_F21_sublist = []
for i in range(len(index_list)):
    if i < len(index_list)-1:
        best_fitness_F21_sublist.append(best_fitness_F21[index_list[i]:index_list[i+1]])
    else:
        best_fitness_F21_sublist.append(best_fitness_F21[index_list[i]:])
print(len(best_fitness_F21_sublist))
# Out:
# (2318,)
# (15, 10)
# 2318
# The index is 20, the value is -0.515699, the counter is 1, the gap is 20
# The index is 40, the value is -0.534199, the counter is 2, the gap is 20
# The index is 60, the value is -0.830335, the counter is 3, the gap is 20
# The index is 80, the value is -0.827788, the counter is 4, the gap is 20
# The index is 100, the value is -2.886087, the counter is 5, the gap is 20
# The index is 120, the value is -1.236557, the counter is 6, the gap is 20
# The index is 140, the value is -0.838777, the counter is 7, the gap is 20
# The index is 160, the value is -1.189282, the counter is 8, the gap is 20
# The index is 180, the value is -0.675656, the counter is 9, the gap is 20
# The index is 200, the value is -2.520883, the counter is 10, the gap is 20
# The index is 210, the value is -1.912634, the counter is 11, the gap is 10
# The index is 220, the value is -1.119992, the counter is 12, the gap is 10
# The index is 230, the value is -0.732272, the counter is 13, the gap is 10
# The index is 240, the value is -1.117783, the counter is 14, the gap is 10
# The index is 250, the value is -0.620545, the counter is 15, the gap is 10
# The index is 260, the value is -1.602315, the counter is 16, the gap is 10
# The index is 270, the value is -1.620285, the counter is 17, the gap is 10
# The index is 280, the value is -0.860211, the counter is 18, the gap is 10
# The index is 290, the value is -1.423780, the counter is 19, the gap is 10
# The index is 300, the value is -1.732905, the counter is 20, the gap is 10
# The index is 310, the value is -0.919513, the counter is 21, the gap is 10
# The index is 320, the value is -0.718865, the counter is 22, the gap is 10
# The index is 330, the value is -0.837411, the counter is 23, the gap is 10
# The index is 340, the value is -2.377203, the counter is 24, the gap is 10
# The index is 350, the value is -0.572240, the counter is 25, the gap is 10
# The index is 360, the value is -0.706956, the counter is 26, the gap is 10
# The index is 370, the value is -0.959456, the counter is 27, the gap is 10
# The index is 380, the value is -1.385889, the counter is 28, the gap is 10
# The index is 390, the value is -0.781753, the counter is 29, the gap is 10
# The index is 400, the value is -0.484822, the counter is 30, the gap is 10
# The index is 440, the value is -0.639853, the counter is 31, the gap is 40
# The index is 480, the value is -0.511232, the counter is 32, the gap is 40
# The index is 520, the value is -0.562375, the counter is 33, the gap is 40
# The index is 560, the value is -0.520403, the counter is 34, the gap is 40
# The index is 600, the value is -1.352322, the counter is 35, the gap is 40
# The index is 640, the value is -0.745069, the counter is 36, the gap is 40
# The index is 680, the value is -0.834981, the counter is 37, the gap is 40
# The index is 720, the value is -0.512800, the counter is 38, the gap is 40
# The index is 760, the value is -0.697357, the counter is 39, the gap is 40
# The index is 800, the value is -1.286296, the counter is 40, the gap is 40
# The index is 820, the value is -0.476593, the counter is 41, the gap is 20
# The index is 840, the value is -0.500415, the counter is 42, the gap is 20
# The index is 860, the value is -0.667338, the counter is 43, the gap is 20
# The index is 880, the value is -0.944593, the counter is 44, the gap is 20
# The index is 900, the value is -1.051702, the counter is 45, the gap is 20
# The index is 920, the value is -1.280864, the counter is 46, the gap is 20
# The index is 940, the value is -1.623405, the counter is 47, the gap is 20
# The index is 960, the value is -0.937921, the counter is 48, the gap is 20
# The index is 980, the value is -0.588724, the counter is 49, the gap is 20
# The index is 1000, the value is -0.540164, the counter is 50, the gap is 20
# The index is 1020, the value is -0.981666, the counter is 51, the gap is 20
# The index is 1040, the value is -0.598763, the counter is 52, the gap is 20
# The index is 1060, the value is -1.192914, the counter is 53, the gap is 20
# The index is 1080, the value is -0.621310, the counter is 54, the gap is 20
# The index is 1100, the value is -0.533700, the counter is 55, the gap is 20
# The index is 1120, the value is -0.567469, the counter is 56, the gap is 20
# The index is 1140, the value is -0.776364, the counter is 57, the gap is 20
# The index is 1160, the value is -0.895707, the counter is 58, the gap is 20
# The index is 1180, the value is -0.583305, the counter is 59, the gap is 20
# The index is 1200, the value is -0.616279, the counter is 60, the gap is 20
# The index is 1220, the value is -1.041156, the counter is 61, the gap is 20
# The index is 1240, the value is -0.576827, the counter is 62, the gap is 20
# The index is 1260, the value is -0.452393, the counter is 63, the gap is 20
# The index is 1280, the value is -0.787349, the counter is 64, the gap is 20
# The index is 1300, the value is -1.062964, the counter is 65, the gap is 20
# The index is 1320, the value is -0.585068, the counter is 66, the gap is 20
# The index is 1340, the value is -0.583062, the counter is 67, the gap is 20
# The index is 1360, the value is -0.587774, the counter is 68, the gap is 20
# The index is 1380, the value is -1.172420, the counter is 69, the gap is 20
# The index is 1400, the value is -1.567180, the counter is 70, the gap is 20
# The index is 1404, the value is -1.269027, the counter is 71, the gap is 4
# The index is 1408, the value is -1.753306, the counter is 72, the gap is 4
# The index is 1416, the value is -2.921065, the counter is 73, the gap is 8
# The index is 1420, the value is -2.017746, the counter is 74, the gap is 4
# The index is 1424, the value is -0.893236, the counter is 75, the gap is 4
# The index is 1428, the value is -1.937276, the counter is 76, the gap is 4
# The index is 1432, the value is -1.227450, the counter is 77, the gap is 4
# The index is 1436, the value is -1.955973, the counter is 78, the gap is 4
# The index is 1440, the value is -1.953243, the counter is 79, the gap is 4
# The index is 1444, the value is -2.031726, the counter is 80, the gap is 4
# The index is 1448, the value is -1.738162, the counter is 81, the gap is 4
# The index is 1452, the value is -1.562878, the counter is 82, the gap is 4
# The index is 1456, the value is -2.034067, the counter is 83, the gap is 4
# The index is 1460, the value is -1.677110, the counter is 84, the gap is 4
# The index is 1464, the value is -1.166340, the counter is 85, the gap is 4
# The index is 1468, the value is -1.575757, the counter is 86, the gap is 4
# The index is 1472, the value is -1.753705, the counter is 87, the gap is 4
# The index is 1476, the value is -0.888567, the counter is 88, the gap is 4
# The index is 1480, the value is -0.544644, the counter is 89, the gap is 4
# The index is 1520, the value is -0.956456, the counter is 90, the gap is 40
# The index is 1560, the value is -0.989350, the counter is 91, the gap is 40
# The index is 1600, the value is -0.839975, the counter is 92, the gap is 40
# The index is 1640, the value is -0.708162, the counter is 93, the gap is 40
# The index is 1678, the value is -0.612764, the counter is 94, the gap is 38
# The index is 1718, the value is -0.758963, the counter is 95, the gap is 40
# The index is 1758, the value is -0.646792, the counter is 96, the gap is 40
# The index is 1798, the value is -0.451796, the counter is 97, the gap is 40
# The index is 1838, the value is -0.428857, the counter is 98, the gap is 40
# The index is 1878, the value is -0.846786, the counter is 99, the gap is 40
# The index is 1886, the value is -1.345326, the counter is 100, the gap is 8
# The index is 1894, the value is -1.388151, the counter is 101, the gap is 8
# The index is 1902, the value is -1.429430, the counter is 102, the gap is 8
# The index is 1910, the value is -1.882964, the counter is 103, the gap is 8
# The index is 1918, the value is -1.329340, the counter is 104, the gap is 8
# The index is 1926, the value is -0.955198, the counter is 105, the gap is 8
# The index is 1934, the value is -1.026831, the counter is 106, the gap is 8
# The index is 1942, the value is -3.566850, the counter is 107, the gap is 8
# The index is 1950, the value is -2.333980, the counter is 108, the gap is 8
# The index is 1958, the value is -0.764377, the counter is 109, the gap is 8
# The index is 1966, the value is -0.986874, the counter is 110, the gap is 8
# The index is 1974, the value is -2.382489, the counter is 111, the gap is 8
# The index is 1982, the value is -1.533164, the counter is 112, the gap is 8
# The index is 1990, the value is -1.342581, the counter is 113, the gap is 8
# The index is 1998, the value is -1.178247, the counter is 114, the gap is 8
# The index is 2006, the value is -1.408887, the counter is 115, the gap is 8
# The index is 2014, the value is -1.126193, the counter is 116, the gap is 8
# The index is 2022, the value is -1.539850, the counter is 117, the gap is 8
# The index is 2030, the value is -1.465463, the counter is 118, the gap is 8
# The index is 2038, the value is -0.838345, the counter is 119, the gap is 8
# The index is 2058, the value is -0.765393, the counter is 120, the gap is 20
# The index is 2078, the value is -1.571263, the counter is 121, the gap is 20
# The index is 2098, the value is -0.448849, the counter is 122, the gap is 20
# The index is 2118, the value is -0.695605, the counter is 123, the gap is 20
# The index is 2138, the value is -0.715718, the counter is 124, the gap is 20
# The index is 2158, the value is -2.481658, the counter is 125, the gap is 20
# The index is 2178, the value is -1.276689, the counter is 126, the gap is 20
# The index is 2198, the value is -1.173341, the counter is 127, the gap is 20
# The index is 2218, the value is -1.907957, the counter is 128, the gap is 20
# The index is 2238, the value is -1.463188, the counter is 129, the gap is 20
# The index is 2242, the value is -1.435467, the counter is 130, the gap is 4
# The index is 2246, the value is -1.268116, the counter is 131, the gap is 4
# The index is 2250, the value is -3.196839, the counter is 132, the gap is 4
# The index is 2254, the value is -1.090637, the counter is 133, the gap is 4
# The index is 2258, the value is -2.222779, the counter is 134, the gap is 4
# The index is 2262, the value is -4.049480, the counter is 135, the gap is 4
# The index is 2266, the value is -2.617422, the counter is 136, the gap is 4
# The index is 2270, the value is -3.552535, the counter is 137, the gap is 4
# The index is 2274, the value is -3.787204, the counter is 138, the gap is 4
# The index is 2278, the value is -1.203328, the counter is 139, the gap is 4
# The index is 2282, the value is -1.575168, the counter is 140, the gap is 4
# The index is 2286, the value is -1.793454, the counter is 141, the gap is 4
# The index is 2290, the value is -1.765128, the counter is 142, the gap is 4
# The index is 2294, the value is -1.183940, the counter is 143, the gap is 4
# The index is 2298, the value is -4.068204, the counter is 144, the gap is 4
# The index is 2302, the value is -2.392866, the counter is 145, the gap is 4
# The index is 2306, the value is -1.950361, the counter is 146, the gap is 4
# The index is 2310, the value is -1.350113, the counter is 147, the gap is 4
# The index is 2314, the value is -2.369210, the counter is 148, the gap is 4
# 150

# %%
# each sublist, if the len(sublist) < 400, then add zeros to the end of the sublist
for index, i in enumerate(best_fitness_F5_sublist):
    if len(i) < 40:
        for j in range(40-len(i)):
            i.append(np.nan)
    best_fitness_F5_sublist[index] = i

# %%
for index, i in enumerate(best_fitness_F8_sublist):
    if len(i) < 40:
        for j in range(40-len(i)):
            i.append(np.nan)
    best_fitness_F8_sublist[index] = i

# %%
for index, i in enumerate(best_fitness_F21_sublist):
    if len(i) < 40:
        for j in range(40-len(i)):
            i.append(np.nan)
    best_fitness_F21_sublist[index] = i

# %%
best_fitness_F5_sublist = np.array(best_fitness_F5_sublist)
best_fitness_F8_sublist = np.array(best_fitness_F8_sublist)
best_fitness_F21_sublist = np.array(best_fitness_F21_sublist)
print(best_fitness_F5_sublist.shape)
print(best_fitness_F8_sublist.shape)
print(best_fitness_F21_sublist.shape)
# Out:
# (150, 40)
# (150, 40)
# (150, 40)

# %%
print(params)
# Out:
#     num_generations  mutation_rate  num_individuals  crossover_rate  \
# 0           1000000           0.03              200             0.7
# 1           1000000           0.03              200             0.7
# 2           1000000           0.03              200             0.7
# 3           1000000           0.03              100             0.7
# 4           1000000           0.03              100             0.7
# 5           1000000           0.03              100             0.7
# 6           1000000           0.03              200             0.6
# 7           1000000           0.03              200             0.6
# 8           1000000           0.03              200             0.6
# 9           1000000           0.03              100             0.6
# 10          1000000           0.03              100             0.6
# 11          1000000           0.03              100             0.6
# 12          1000000           0.03              200             0.7
# 13          1000000           0.03              200             0.7
# 14          1000000           0.03              200             0.7
#
#    mutation_type           crossover_type  local_search_rate  \
# 0         Normal  Probabilistic_crossover                0.5
# 1         Normal  Probabilistic_crossover                0.5
# 2         Normal  Probabilistic_crossover                0.5
# 3         Normal  Probabilistic_crossover                0.5
# 4         Normal  Probabilistic_crossover                0.5
# 5         Normal  Probabilistic_crossover                0.5
# 6         Normal  Probabilistic_crossover                0.5
# 7         Normal  Probabilistic_crossover                0.5
# 8         Normal  Probabilistic_crossover                0.5
# 9         Normal  Probabilistic_crossover                0.5
# 10        Normal  Probabilistic_crossover                0.5
# 11        Normal  Probabilistic_crossover                0.5
# 12        Normal  Probabilistic_crossover                0.5
# 13        Normal  Probabilistic_crossover                0.5
# 14        Normal  Probabilistic_crossover                0.5
#
#    local_search_type  search_radius  threshold  dimensions    gg  \
# 0            Uniform           0.05     0.0001         100  0.05
# 1            Uniform           0.05     0.0001         100  0.05
# 2            Uniform           0.05     0.0001         100  0.05
# 3            Uniform           0.05     0.0001         100  0.05
# 4            Uniform           0.05     0.0001         100  0.05
# 5            Uniform           0.05     0.0001         100  0.05
# 6            Uniform           0.05     0.0001         100  0.05
# 7            Uniform           0.05     0.0001         100  0.05
# 8            Uniform           0.05     0.0001         100  0.05
# 9            Uniform           0.05     0.0001         100  0.05
# 10           Uniform           0.05     0.0001         100  0.05
# 11           Uniform           0.05     0.0001         100  0.05
# 12           Uniform           0.05     0.0001         100  0.05
# 13           Uniform           0.05     0.0001         100  0.05
# 14           Uniform           0.05     0.0001         100  0.05
#
#          selection_method  length_of_local_search  redo_local_search_rate  \
# 0   sorted_selection_part                       1                       0
# 1   sorted_selection_part                       1                       0
# 2   sorted_selection_part                       1                       0
# 3   sorted_selection_part                       1                       0
# 4   sorted_selection_part                       1                       0
# 5   sorted_selection_part                       1                       0
# 6   sorted_selection_part                       4                       0
# 7   sorted_selection_part                       4                       0
# 8   sorted_selection_part                       4                       0
# 9   sorted_selection_part                       4                       0
# 10  sorted_selection_part                       4                       0
# 11  sorted_selection_part                       4                       0
# 12  sorted_selection_part                       4                       0
# 13  sorted_selection_part                       4                       0
# 14  sorted_selection_part                       4                       0
#
#     fitness_function algorithm
# 0                  5  Baseline
# 1                  5   Lamarck
# 2                  5   Baldwin
# 3                  5  Baseline
# 4                  5   Lamarck
# 5                  5   Baldwin
# 6                  5  Baseline
# 7                  5   Lamarck
# 8                  5   Baldwin
# 9                  5  Baseline
# 10                 5   Lamarck
# 11                 5   Baldwin
# 12                 5  Baseline
# 13                 5   Lamarck
# 14                 5   Baldwin

# %%
# make index, 150 rows
df_index = [] # [Baseline*10,Lamarck*10, Baldwin*10] *5
for i in range(5):
    for j in ['Baseline', 'Lamarck', 'Baldwin']:
        for k in range(10):
            df_index.append(j)
print(df_index)
# make column names, iteration 1-40 gaps
df_columns = [1] + [i*50 for i in range(1,40)]
print(len(df_columns))
# Out:
# ['Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Baseline', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Lamarck', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin', 'Baldwin']
# 40

# %%
# make a dataframe for best_fitness_F5_sublist
best_fitness_F5_sublist_df = pd.DataFrame(best_fitness_F5_sublist)
best_fitness_F5_sublist_df.columns = df_columns
best_fitness_F5_sublist_df['Algorithm'] = df_index
best_fitness_F5_sublist_df['Function'] = ['F5' for _ in range(150)]

print(best_fitness_F5_sublist_df.shape)
best_fitness_F8_sublist_df = pd.DataFrame(best_fitness_F8_sublist)
best_fitness_F8_sublist_df.columns = df_columns
best_fitness_F8_sublist_df['Algorithm'] = df_index
best_fitness_F8_sublist_df['Function'] = ['F8' for _ in range(150)]

print(best_fitness_F8_sublist_df.shape)
best_fitness_F21_sublist_df = pd.DataFrame(best_fitness_F21_sublist)
best_fitness_F21_sublist_df.columns = df_columns
best_fitness_F21_sublist_df['Algorithm'] = df_index
best_fitness_F21_sublist_df['Function'] = ['F21' for _ in range(150)]
print(best_fitness_F21_sublist_df.shape)
# Out:
# (150, 42)
# (150, 42)
# (150, 42)

# %%
print(best_fitness_F5_sublist_df)
# Out:
#                 1            50           100           150           200  \
# 0    9.152567e+08  2.924126e+08  1.299142e+08  6.417488e+07  3.415174e+07
# 1    1.077707e+09  3.580456e+08  1.640735e+08  8.742370e+07  5.252735e+07
# 2    9.569201e+08  3.005727e+08  1.305862e+08  8.269918e+07  5.326927e+07
# 3    1.016850e+09  3.162292e+08  1.123450e+08  7.887601e+07  4.943015e+07
# 4    1.024720e+09  3.220951e+08  1.678182e+08  9.907548e+07  5.942760e+07
# ..            ...           ...           ...           ...           ...
# 145  8.485037e+08  3.481239e+08  1.166817e+08  5.687329e+07           NaN
# 146  1.005545e+09  2.587348e+08  8.889466e+07  5.260394e+07           NaN
# 147  1.095066e+09  2.716496e+08  1.005946e+08  5.879772e+07           NaN
# 148  9.200279e+08  3.112842e+08  1.557298e+08  8.153157e+07           NaN
# 149  9.480711e+08  3.037566e+08  1.182084e+08  6.917859e+07           NaN
#
#               250           300           350           400           450  \
# 0    1.787178e+07  9.014610e+06  4.877578e+06  3.075118e+06  1.752351e+06
# 1    2.445500e+07  1.206373e+07  7.368348e+06  3.154165e+06  1.733565e+06
# 2    3.187146e+07  1.880901e+07  1.015042e+07  5.065898e+06  2.835877e+06
# 3    2.632301e+07  1.429097e+07  7.155996e+06  3.942256e+06  2.387468e+06
# 4    3.271335e+07  1.922929e+07  1.165604e+07  6.722713e+06  3.595421e+06
# ..            ...           ...           ...           ...           ...
# 145           NaN           NaN           NaN           NaN           NaN
# 146           NaN           NaN           NaN           NaN           NaN
# 147           NaN           NaN           NaN           NaN           NaN
# 148           NaN           NaN           NaN           NaN           NaN
# 149           NaN           NaN           NaN           NaN           NaN
#
#      ...  1600  1650  1700  1750  1800  1850  1900  1950  Algorithm  Function
# 0    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   Baseline        F5
# 1    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   Baseline        F5
# 2    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   Baseline        F5
# 3    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   Baseline        F5
# 4    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   Baseline        F5
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...        ...       ...
# 145  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    Baldwin        F5
# 146  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    Baldwin        F5
# 147  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    Baldwin        F5
# 148  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    Baldwin        F5
# 149  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    Baldwin        F5
#
# [150 rows x 42 columns]

# %%
# save this dataframe
best_fitness_sublist_df = pd.concat([best_fitness_F5_sublist_df, best_fitness_F8_sublist_df, best_fitness_F21_sublist_df], axis=0)
print(best_fitness_sublist_df.shape)
print(best_fitness_sublist_df)
# Out:
# (450, 42)
#                 1            50           100           150           200  \
# 0    9.152567e+08  2.924126e+08  1.299142e+08  6.417488e+07  3.415174e+07
# 1    1.077707e+09  3.580456e+08  1.640735e+08  8.742370e+07  5.252735e+07
# 2    9.569201e+08  3.005727e+08  1.305862e+08  8.269918e+07  5.326927e+07
# 3    1.016850e+09  3.162292e+08  1.123450e+08  7.887601e+07  4.943015e+07
# 4    1.024720e+09  3.220951e+08  1.678182e+08  9.907548e+07  5.942760e+07
# ..            ...           ...           ...           ...           ...
# 145 -4.068204e+00 -9.434621e+00 -9.988627e+00 -1.011023e+01           NaN
# 146 -2.392866e+00 -4.623758e+00 -4.623758e+00 -5.016689e+00           NaN
# 147 -1.950361e+00 -6.216274e+00 -9.229233e+00 -9.617119e+00           NaN
# 148 -1.350113e+00 -2.627611e+00 -2.653764e+00 -2.673058e+00           NaN
# 149 -2.369210e+00 -5.442407e+00 -9.424627e+00 -9.424627e+00           NaN
#
#               250           300           350           400           450  \
# 0    1.787178e+07  9.014610e+06  4.877578e+06  3.075118e+06  1.752351e+06
# 1    2.445500e+07  1.206373e+07  7.368348e+06  3.154165e+06  1.733565e+06
# 2    3.187146e+07  1.880901e+07  1.015042e+07  5.065898e+06  2.835877e+06
# 3    2.632301e+07  1.429097e+07  7.155996e+06  3.942256e+06  2.387468e+06
# 4    3.271335e+07  1.922929e+07  1.165604e+07  6.722713e+06  3.595421e+06
# ..            ...           ...           ...           ...           ...
# 145           NaN           NaN           NaN           NaN           NaN
# 146           NaN           NaN           NaN           NaN           NaN
# 147           NaN           NaN           NaN           NaN           NaN
# 148           NaN           NaN           NaN           NaN           NaN
# 149           NaN           NaN           NaN           NaN           NaN
#
#      ...  1600  1650  1700  1750  1800  1850  1900  1950  Algorithm  Function
# 0    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   Baseline        F5
# 1    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   Baseline        F5
# 2    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   Baseline        F5
# 3    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   Baseline        F5
# 4    ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   Baseline        F5
# ..   ...   ...   ...   ...   ...   ...   ...   ...   ...        ...       ...
# 145  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    Baldwin       F21
# 146  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    Baldwin       F21
# 147  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    Baldwin       F21
# 148  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    Baldwin       F21
# 149  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN    Baldwin       F21
#
# [450 rows x 42 columns]

# %%
best_fitness_sublist_df.to_csv('best_fitness_sublist_df.csv', sep=',', header=True, index=False)
